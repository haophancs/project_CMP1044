# %% [markdown]
# ## Compose data

# %%
import os
import numpy as np
import pandas as pd

# %%
datasets = ["yelpchi", "yelpnyc"]

def read_ds(ds_name):
    result = pd.read_excel("../datasets/processed/{0}_reviews_calculated.xlsx".format(ds_name))
    result["dataset"] = ds_name
    result = result[[result.columns[-1], *result.columns[:-1]]]
    return result

df = pd.concat(
    [read_ds(ds_name) for ds_name in datasets], 
    ignore_index=True,
)

df.head()
# Out:
#    dataset                user              product  rating    label  \
# 0  yelpchi  yelpchi_user_00000  yelpchi_product_000       5  organic
# 1  yelpchi  yelpchi_user_00001  yelpchi_product_000       3  organic
# 2  yelpchi  yelpchi_user_00002  yelpchi_product_000       5  organic
# 3  yelpchi  yelpchi_user_00003  yelpchi_product_000       1  organic
# 4  yelpchi  yelpchi_user_00004  yelpchi_product_000       3  organic
#
#          date                                       content_text  \
# 0  2011-06-08  Let me begin by saying that there are two kind...
# 1  2011-08-30  The only place inside the Loop that you can st...
# 2  2009-06-26  I have walked by the Tokyo Hotel countless tim...
# 3  2010-09-16  If you are considering staying here, watch thi...
# 4  2010-02-05  This place is disgusting, absolutely horrible,...
#
#    content_polarity  content_subjectivity  \
# 0             0.025                 0.570
# 1            -0.047                 0.625
# 2             0.172                 0.615
# 3             0.250                 0.333
# 4            -0.435                 0.505
#
#                                        content_words  \
# 0  ['Let', 'me', 'begin', 'by', 'saying', 'that',...
# 1  ['The', 'only', 'place', 'inside', 'the', 'Loo...
# 2  ['I', 'have', 'walked', 'by', 'the', 'Tokyo', ...
# 3  ['If', 'you', 'are', 'considering', 'staying',...
# 4  ['This', 'place', 'is', 'disgusting', 'absolut...
#
#                                    content_sentences content_emotion
# 0  ["Let me begin by saying that there are two ki...         neutral
# 1  ['The only place inside the Loop that you can ...         neutral
# 2  ['I have walked by the Tokyo Hotel countless t...         neutral
# 3  ['If you are considering staying here, watch t...         neutral
# 4  ['This place is disgusting, absolutely horribl...         disgust

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 426335 entries, 0 to 426334
# Data columns (total 11 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   dataset               426335 non-null  object
#  1   user                  426335 non-null  object
#  2   product               426335 non-null  object
#  3   rating                426335 non-null  int64
#  4   label                 426335 non-null  object
#  5   date                  426335 non-null  object
#  6   content_text          426335 non-null  object
#  7   content_polarity      426335 non-null  float64
#  8   content_subjectivity  426335 non-null  float64
#  9   content_words         426335 non-null  object
#  10  content_emotion       426335 non-null  object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 35.8+ MB

# %%
df = df.drop(columns=["content_sentences"])
df.content_words = df.content_words.apply(
    lambda content_words: list(map(lambda s: s.strip("'"), content_words.lstrip("[").rstrip("]").split(", ")))
)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 426335 entries, 0 to 426334
# Data columns (total 11 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   dataset               426335 non-null  object
#  1   user                  426335 non-null  object
#  2   product               426335 non-null  object
#  3   rating                426335 non-null  int64
#  4   label                 426335 non-null  object
#  5   date                  426335 non-null  object
#  6   content_text          426335 non-null  object
#  7   content_polarity      426335 non-null  float64
#  8   content_subjectivity  426335 non-null  float64
#  9   content_words         426335 non-null  object
#  10  content_emotion       426335 non-null  object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 35.8+ MB

# %%
df.to_json("../datasets/processed/yelp_mongo_dumping.json", orient='records')

# %% [markdown]
# ## Dump to MongoDB

# %%
data_path = os.path.abspath("../datasets/processed/yelp_mongo_dumping.json")

# !docker stop mongo 
# !docker volume remove mongodbdata && docker volume create mongodbdata
# !docker run \
    -v mongodbdata:/data/db \
    -v {data_path}:/data/yelp_mongo_dumping.json \
    -p 27017:27017 \
    --rm -it -d --name mongo mongo
# Out:
# mongo
# mongodbdata
# mongodbdata
# 557c59e5e101cef9f75d9da0ecf2b8f7b42574bb2aaa76898a096c7678af8202

# %%
# !docker exec -it mongo mongoimport \
    --uri "mongodb://localhost:27017/?retryWrites=true&w=majority" \
    --collection="yelp_reviews" \
    --db cmp1044 \
    --collection yelp_reviews \
    --file /data/yelp_mongo_dumping.json \
    --jsonArray
# Out:
# 2024-01-11T05:37:52.078+0000	connected to: mongodb://localhost:27017/?retryWrites=true&w=majority
# 2024-01-11T05:37:55.078+0000	[........................] cmp1044.yelp_reviews	29.4MB/731MB (4.0%)
# 2024-01-11T05:37:58.079+0000	[##......................] cmp1044.yelp_reviews	64.5MB/731MB (8.8%)
# 2024-01-11T05:38:01.080+0000	[###.....................] cmp1044.yelp_reviews	97.6MB/731MB (13.4%)
# 2024-01-11T05:38:04.079+0000	[####....................] cmp1044.yelp_reviews	131MB/731MB (18.0%)
# 2024-01-11T05:38:07.079+0000	[#####...................] cmp1044.yelp_reviews	166MB/731MB (22.7%)
# 2024-01-11T05:38:10.080+0000	[######..................] cmp1044.yelp_reviews	200MB/731MB (27.3%)
# 2024-01-11T05:38:13.079+0000	[#######.................] cmp1044.yelp_reviews	235MB/731MB (32.1%)
# 2024-01-11T05:38:16.086+0000	[########................] cmp1044.yelp_reviews	267MB/731MB (36.5%)
# 2024-01-11T05:38:19.079+0000	[#########...............] cmp1044.yelp_reviews	298MB/731MB (40.8%)
# 2024-01-11T05:38:22.079+0000	[##########..............] cmp1044.yelp_reviews	330MB/731MB (45.1%)
# 2024-01-11T05:38:25.079+0000	[###########.............] cmp1044.yelp_reviews	362MB/731MB (49.5%)
# 2024-01-11T05:38:28.080+0000	[############............] cmp1044.yelp_reviews	387MB/731MB (53.0%)
# 2024-01-11T05:38:31.080+0000	[#############...........] cmp1044.yelp_reviews	420MB/731MB (57.5%)
# 2024-01-11T05:38:34.080+0000	[##############..........] cmp1044.yelp_reviews	451MB/731MB (61.7%)
# 2024-01-11T05:38:37.080+0000	[###############.........] cmp1044.yelp_reviews	482MB/731MB (66.0%)
# 2024-01-11T05:38:40.080+0000	[################........] cmp1044.yelp_reviews	516MB/731MB (70.7%)
# 2024-01-11T05:38:43.080+0000	[##################......] cmp1044.yelp_reviews	551MB/731MB (75.4%)
# 2024-01-11T05:38:46.081+0000	[###################.....] cmp1044.yelp_reviews	582MB/731MB (79.7%)
# 2024-01-11T05:38:49.081+0000	[####################....] cmp1044.yelp_reviews	613MB/731MB (83.9%)
# 2024-01-11T05:38:52.086+0000	[#####################...] cmp1044.yelp_reviews	646MB/731MB (88.5%)
# 2024-01-11T05:38:55.081+0000	[######################..] cmp1044.yelp_reviews	678MB/731MB (92.8%)
# 2024-01-11T05:38:58.082+0000	[#######################.] cmp1044.yelp_reviews	710MB/731MB (97.2%)
# 2024-01-11T05:39:00.018+0000	[########################] cmp1044.yelp_reviews	731MB/731MB (100.0%)
# 2024-01-11T05:39:00.018+0000	426335 document(s) imported successfully. 0 document(s) failed to import.

# %%
import urllib.parse
from pymongo import MongoClient
client = MongoClient("mongodb://localhost:27017/test")

collection = client.cmp1044.yelp_reviews
cursor = collection.find({})
df_dumped = pd.DataFrame(cursor)
df_dumped.head()
# Out:
#                         _id  dataset                user              product  \
# 0  659f7eb07722ec561c229b73  yelpchi  yelpchi_user_00001  yelpchi_product_000
# 1  659f7eb07722ec561c229b74  yelpchi  yelpchi_user_00004  yelpchi_product_000
# 2  659f7eb07722ec561c229b75  yelpchi  yelpchi_user_00005  yelpchi_product_000
# 3  659f7eb07722ec561c229b76  yelpchi  yelpchi_user_00000  yelpchi_product_000
# 4  659f7eb07722ec561c229b77  yelpchi  yelpchi_user_00007  yelpchi_product_001
#
#    rating    label        date  \
# 0       3  organic  2011-08-30
# 1       3  organic  2010-02-05
# 2       1  organic  2010-08-09
# 3       5  organic  2011-06-08
# 4       2  organic  2012-07-09
#
#                                         content_text  content_polarity  \
# 0  The only place inside the Loop that you can st...            -0.047
# 1  This place is disgusting, absolutely horrible,...            -0.435
# 2  Disgusting!!! There is literally duct tape hol...            -0.265
# 3  Let me begin by saying that there are two kind...             0.025
# 4  Good location, really run down. I am surprised...             0.211
#
#    content_subjectivity                                      content_words  \
# 0                 0.625  [The, only, place, inside, the, Loop, that, yo...
# 1                 0.505  [This, place, is, disgusting, absolutely, horr...
# 2                 0.557  [Disgusting, There, is, literally, duct, tape,...
# 3                 0.570  [Let, me, begin, by, saying, that, there, are,...
# 4                 0.497  [Good, location, really, run, down, I, am, sur...
#
#   content_emotion
# 0         neutral
# 1         disgust
# 2         disgust
# 3         neutral
# 4        surprise
